# %% [markdown]
# # Analytic Bayesian Methods
#
# In some instances, the use of specific combinations of likelihoods and priors
# can result in closed-form analytical solutions for the posterior distribution,
# circumventing the need for numerical integration. In these scenarios, when a
# prior and posterior are of the same probability distribution, the prior and
# posterior are called conjugate distributions and the prior is called the
# [conjugate prior](https://en.wikipedia.org/wiki/Conjugate_prior) for the
# likelihood.
#
# ## Table of Conjugate Distributions for Common Likelihoods
#
# Variable convention.
#
# |||
# |:-:|:-:|
# |Model Likelihood $p(x|\Theta)$ | $Binomial(x|n,p)$ |
# |Model Parameters $\Theta$| $n$ (number of trials), <br> $p$ (probability of success) |
# |Marginalized Parameter $\theta$|$p$ (probability of success)|
# |Marginal Parameters $\Theta-\{\theta\}$|$n$ (number of trials)|
# |Conjugate Prior| $Beta(p|\alpha,\beta)$ |
# |Conjugate Posterior| $Beta(p|\alpha',\beta')$ where <br> $\alpha'=\alpha+s$ and <br> $\beta'=\beta+f$ |
# | Conjugate Hyperparameters |$\alpha$ prior successes, <br> $\beta$ prior failures, <br> $|\mathbb{X}|$ observed trials, <br> $s=\sum_$ observed successes, <br> $f=|\mathbb{X}|-s$ observed failures |
#
#
#
#
# <table>
#     <tr>
#         <td><b>Model Likelihood Function $p(y|\Theta)$ </b></td>
#         <td><b>Model Parameters $\Theta$ </b></td>
#         <td><b>Conjugate Prior $p(\theta)$ </b></td>
#         <td><b>Conjugate Posterior $p(\theta|\textbf{X})$ </b></td>
#         <td><b>Conjugate Hyperparameters</b></td>
#         <td><b>Posterior Predictive Distribution $p(\tilde{y}|\textbf{X})$</b></td>
#     </tr>
#     <tr>
#         <td> $Binomial(k|t,p)$ </td>
#         <td> $t$ (number of trials), <br> $p$ (probability of success) </td>
#         <td> $Beta(p|\alpha,\beta)$ </td>
#         <td> $Beta(p|\alpha',\beta')$ where <br> $\alpha'=\alpha+s$ and <br> $\beta'=\beta+f$ </td>
#         <td> $\alpha$ prior successes, <br> $\beta$ prior failures, <br> $n$ observed trials, <br> $s$ observed successes, <br> $f=n-s$ observed failures </td>
#         <td> $BetaBinomial(\tilde{k}|t,\alpha',\beta')$ </td>
#     </tr>
#     <tr>
#         <td> $Poisson(k|\lambda)$ </td>
#         <td> $\lambda$ (rate) </td>
#         <td> $Gamma(\lambda|\alpha,\beta)$ </td>
#         <td> $Gamma(\lambda|\alpha',\beta')$ where <br> $\alpha'=\alpha+n$ and <br> $\beta'=\beta+i$ </td>
#         <td> $\alpha$ prior occurrences, <br> $\beta$ prior intervals, <br> $n$ observed occurrences, <br> $i$ observed intervals </td>
#         <td> $NegativeBinomial(\tilde{k}|\alpha',\frac{\beta'}{1+\beta'})$ </td>
#     </tr>
#     <tr>
#         <td> $Categorical(k|c,\textbf{P})$ </td>
#         <td> $c$ (number of categories), <br> $\textbf{P}$ (set of probabilities <br> {$p_1,...,p_c$} for each category) <br> s.t. $\sum\textbf{P}=1$ and every $p\ge0$ </td>
#         <td> $Dirichlet(\lambda|\alpha,\beta)$ </td>
#         <td> $Dirichlet(\lambda|\alpha',\beta')$ where <br> $\alpha'=\alpha+n$ and <br> $\beta'=\beta+i$ </td>
#         <td> $\alpha$ prior occurrences, <br> $\beta$ prior intervals, <br> $n$ observed occurrences, <br> $i$ observed intervals </td>
#         <td> $NegativeBinomial(\tilde{k}|\alpha',\frac{\beta'}{1+\beta'})$ </td>
#     </tr>
#
# </table>
#
#
# The following pages will delve further into these conjugate priors and show
# through worked examples how to apply them in appropriate scenarios.
